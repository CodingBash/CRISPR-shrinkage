# %%
import docker

# %%
import docker
client = docker.from_env()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\bbece\AppData\Local\pypoetry\Cache\virtualenvs\crispr-shrinkage-qyTOZuOA-py3.8\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\bbece\AppData\Local\pypoetry\Cache\virtualenvs\crispr-shrinkage-qyTOZuOA-py3.8\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# ...

# %%
client.containers.run("ubuntu:latest", "echo hello world")
'hello world\n'
